# %% [markdown]
# # Imports and I/O

# %%
# Imports
import sys
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns



# Configs
# %config InlineBackend.figure_format ='retina'
# %matplotlib inline

# Cython
# %load_ext Cython
#!python
#cython: language_level=3

print("All libraries set-up and ready to go!")
# Out:
# All libraries set-up and ready to go!

# %%
suffix = ''
# keystroke,word,sentence,file,user dataframe
k = pd.read_csv('../../pads/keystrokes' + suffix + '.csv', index_col=False, encoding='latin1')
w = pd.read_csv('../../pads/words' + suffix + '.csv', index_col=False)
s = pd.read_csv('../../pads/sentences' + suffix + '.csv', index_col=False)
f = pd.read_csv('../../pads/files' + suffix + '.csv', index_col=False)
u = pd.read_csv('../../pads/users' + suffix + '.csv', index_col=False)
# all bigrams in data
bi_gram = pd.read_csv('../../pads/bigrams.csv')
# all bigrams that occurred more than 3 times in data
bi_gram3 = pd.read_csv('../../pads/bigrams3.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f60256ce5991> in <module>()
#       7 u = pd.read_csv('../../pads/users' + suffix + '.csv', index_col=False)
#       8 # all bigrams in data
# ----> 9 bi_gram = pd.read_csv('../../pads/bigrams.csv')
#      10 # all bigrams that occurred more than 3 times in data
#      11 bi_gram3 = pd.read_csv('../../pads/bigrams3.csv')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'../../pads/bigrams.csv' does not exist

# %%
# Average of log(n-gram frequency+1) possible n-grams within burst and across burst 
# per each file
# in order of bigram-2*median pause length, 550ms, 1000ms, 2000ms and trigram
burst_bigr_freq_550 = pd.read_csv('../../pads/burstbigrfreq.csv',index_col=False)
burst_bigr_freq_1000 = pd.read_csv('../../pads/burstbigrfreq_1000.csv',index_col=False)
burst_bigr_freq_2000 = pd.read_csv('../../pads/burstbigrfreq_2000.csv',index_col=False)
burst_bigr_freq_tmed = pd.read_csv('../../pads/burstbigrfreq_tmed.csv',index_col=False)
burst_trgr_freq_550 = pd.read_csv('../../pads/bursttrgrfreq_500.csv',index_col=False)
burst_trgr_freq_1000 = pd.read_csv('../../pads/bursttrgrfreq_1000.csv',index_col=False)
burst_trgr_freq_2000 = pd.read_csv('../../pads/bursttrgrfreq_2000.csv',index_col=False)
burst_trgr_freq_tmed = pd.read_csv('../../pads/bursttrgrfreq_tmed.csv',index_col=False)

# %%
# Average burst length, mean, median pause length for each file
bst_550 =  pd.read_csv('../../pads/bst_550.csv')
bst_1000 = pd.read_csv('../../pads/bst_1000.csv')
bst_2000 = pd.read_csv('../../pads/bst_2000.csv')

# %% [markdown]
# ## Plot Helper Function

# %%
def plotDistributions(data1, data2, label1='data1', label2='data2', x_label='variable'):
    
    m = min(data1.quantile(0.01), data2.quantile(0.01))
    M = max(data1.quantile(0.99), data2.quantile(0.99))
    bins = np.linspace(m, M, 100)

    fig, axs = plt.subplots(2, gridspec_kw={'height_ratios': [1, 4]})
    fig.set_size_inches(20, 8)

    #plt.hold = True
    #boxes=[singleClause, multiClause]
    #axs[0].boxplot(boxes,vert=0)
    #axs[0].set(xlim=(m, M))

    axs[0].set(xlim=(m, M))
    my_pal = {0: "g", 1: "r"}
    sns.boxplot(data=[data1, data2],  orient='h' , ax=axs[0], palette=my_pal)

    axs[1].hist(data1, bins, alpha=0.4, label=label1, color='g')
    axs[1].hist(data2, bins, alpha=0.3, label=label2, color='r')
    axs[1].axvline(x=data1.mean(), c='g', lw=2)
    axs[1].axvline(x=data2.mean(), c='r', lw=2)
    axs[1].set(xlim=(m, M))


    plt.legend(loc='upper right')
    plt.xlabel(x_label)
    plt.show()

# %% [markdown]
# # Iterator helper for computation

# %%
# Runs in approx. 50s
k_sorted = k.sort_values(by='s_id')
rs = 0; re = 0; ranges = {}
for idx, val in k_sorted['s_id'].value_counts().sort_index().iteritems():
    re += val
    ranges[idx] = (rs, re)
    rs += val
    
for s_id, row in s.iterrows():
    if ranges.get(s_id) != None:
        u, v = ranges.get(s_id)
        k_sentence = k_sorted.iloc[u:v, :]
    else:
        k_sentence = k_sorted.iloc[0:0, :]
    
    ###### YOUR CODE HERE #####
    ## Will run ranging over sentence with s_id, row, k_sentence ##
    ## Example: s.at[s_id, 'ks_len'] = len(k_sentence) / len(row['text'])

# %% [markdown]
# # Part of Speech

# %% [raw]
# import nltk
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

# %% [raw]
# print(len(w))
# for i in range(len(w)):
#     word = str(w.at[i,'text'])
#     tagged = nltk.pos_tag([word])[0]
#     w.at[i,'partofspeech'] = tagged[1]
#     if i%10000 == 0:
#         print(i)

# %% [raw]
# w.to_csv('../../pads/words-partofspeech.csv', index=False)

# %%
pos = pd.DataFrame()
pos['t/len_filter_10000'] = w.groupby(by='partofspeech')['t/len_filter_10000'].median()
pos['t'] = w.groupby(by='partofspeech')['t'].median()
pos['t/len'] = w.groupby(by='partofspeech')['t/len'].median()

# %%
pos['word_freq'] = w.groupby(by='partofspeech')['word_freq'].median()

# %%
fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx()
width = 0.4

pos['t/len_filter_10000'].plot(kind='bar', color='red', ax=ax, width=width, position=1)
pos['word_freq'].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_ylabel('t')
ax2.set_ylabel('word frequency')

# %% [raw]
# w0 = w[w['f_id'] == 1]
# pspcol = []
# tcol = []
# tcolmed = []
# print(len(w0))
# for i in range(len(w0)):
#     partsp = w0.iloc[i]['partofspeech']
#     wordtime = k[(k['pos']>w0.iloc[i]['start_pos']) & (k['pos']<=w0.iloc[i]['end_pos'])&(k['t']<10000)]['t'].mean()
#     wordtimemed = k[(k['pos']>w0.iloc[i]['start_pos']) & (k['pos']<=w0.iloc[i]['end_pos'])&(k['t']<10000)]['t'].median()
#     pspcol.append(partsp)
#     tcol.append(wordtime)
#     tcolmed.append(wordtimemed)
#     if i%10==0:
#         print(i)

# %%
pspdf = pd.DataFrame(list(zip(pspcol, tcol,tcolmed)),columns = ['part of speech','tmean','tmed'])
timebypsp = pspdf.groupby(by='part of speech')['tmean'].mean().sort_values()
timebypsp
# Out:
# part of speech
# JJS     365.643156
# PRP$    367.890266
# VBD     372.839891
# WDT     374.120505
# JJR     374.448898
# VBN     375.272113
# NNP     376.115897
# VB      376.555086
# WRB     376.697730
# NNS     377.614029
# WP      377.701884
# NN      378.161022
# TO      378.249154
# IN      379.221804
# VBZ     380.657284
# DT      380.669622
# RB      380.844786
# JJ      381.099811
# VBP     381.910139
# VBG     382.695833
# RBR     382.751690
# MD      382.769485
# CC      383.557773
# PRP     383.589051
# EX      383.750181
# CD      386.589660
# Name: tmean, dtype: float64

# %% [markdown]
# # Words

# %% [raw]
# w[['word_freq', 'spell_err']].boxplot(by='spell_err')

# %% [raw]
# ax = w[w['spell_err']==1].plot.scatter(x = 'word_freq',y='spell_err',c = 'Red')
# w[w['spell_err']==0].plot.scatter(x = 'word_freq',y='spell_err',c = 'DarkBlue',ax = ax)

# %%
w['word_freq'].hist(bins=100)

# %%
wf = w.sort_values(by=['word_freq'],ascending =False)
words = wf['text'].tolist()

# %% [markdown]
# # Pause & Burst

# %%
def get_burstlist(file_id,p_threshold):
    burstlst = []
    stsid = f.loc[file_id,'s_id_s']
    steid = f.loc[file_id,'s_id_e']
    k_in_f = k[(k['s_id']>=stsid)&(k['s_id']<=steid)]
    tmean = k_in_f['t'].mean()
    tmed = k_in_f['t'].median()
    prev = k_in_f.index[0]
    for i in range(len(k_in_f)):
        ks = k_in_f.iloc[i]
        if ks['t'] > p_threshold:
            if k_in_f.index[i]-1 < prev:
                burstlst.append((prev,prev,0))
            else:
                burstlst.append((prev,k_in_f.index[i],ks['t']))
            prev = k_in_f.index[i]
    return burstlst,tmean,tmed

# %%
blist,tmean,tmed = get_burstlist(100,2000)
# blist,_,_ = get_burstlist(100,2*tmed)
for burst in blist:
    print(''.join(str(st).replace('nan','←') for st in k[burst[0]:burst[1]]['char'].values),end='')
    print(' {'+str(burst[2])+'}',end='')
# Out:
#  {0}Learne←←←←←← {2298}The term Learner Corpus comprises a cin←←oncept...\n- ←←deisg←←←sign considerations for compiling lean←rner corpora {2452}\na←example of a nwe←←ew, cm←ompiled learner corpus sre←←←resource to ills←ustrate u←such cos←nsideratiosn←←ns\n\n {124925}← {124925}← {124925}← {124926}← {124925}← {124925}← {124926}←collection of texts that are being produced by second lam←nguage learners.  {4621}←←←←T← These texts are co←← {6958}saved  {6001}in an electronic  {18908} form. {8345} The←←←It {4708} can be helpflu←←ul i ←n order to  {20482}←←←←←←←←←← {8508}←←regarding the second language acu←←←←←qu {2728}isition research. Fur←t←rh←thermore  {10088}these text {2212}s can be  {2947}used to ←←←in order to identify typic {3364}al problmes of  {11511}←←←←←←←ems  {5630}certain  {3591}groups have whilst learning a second language.  {25218}I←← There are certaind←  {2925}designs that have to v←be considered in order to compile a c←learner corpus ←.  {3054}← {3055}← {3054}← {3055}← {3055}←←The←←←The Corp←←←←corpus can {13849}←←, which I am gp←oing to describe in the followin.←g. {24925} These cons←←←←←←← so {9490}-called Design considerations can be  {44295}summed up  {3617}as the language-relatee criteria, d←the task-related criteria and the e←learner-related criteria. {292660}←d {56853} The language←d-related criteria inclu←←←←← {6036}implies characteristics {2577} like  {7082}←←←←←rg←egarding the mode- wether it is written or spoken, the gern←←nre,  {3014}the style of a text and its topic. The learner-related criteria includes  {8190}information abpu←←out the {3394} learner, such as his backg←←←←← {2567}f←natuve ←←←←ive language, his  {11546}surroundings and internal adp←←spects.  {3196}The T←task- {271852}relae←te ch←←d {3710}←←d criteria  {18455}are concerned with  {2623}aspects like  {2256}whete←her re←←←←←←←←←←← the references used for the text,  {8195}temproa←←←oral limitation  {59150}and whether it was a {11787}←←←←←←←←the text was writtr←en spontanou {2077}←← {3987}eously or  {17142}wih←th prepart←←←aration. {10390} Including  {5624}t←such considerations, I am now going tio gi←←←←←o give an example for a new, compiled learner corpus. {57081} resource {3300}possible  {7095}← ←←←←←←←←←←  {111924} This corpus could  {17037}comÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¼ros←←←←ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¼ri←←←prise  {26115}t {26116}exts from beginnger t←←←←←ers to interme←←←rmediae←te.←-mud←←id.  {12682}The language←←←←←←←←target language that is being observed←←←←←←←←←←←←←←←←←←←←←←of this corpus could be French and {4788}  {2608}the learnes co←ould have german, dutch, enl←glish, polish and vietnam←←←←←←←←←←←←←←←←←←←←←←←←←←←←←← {3562}h, english, spaniish←←←sh and polish as first language.  {108795}Considering  {2571}the ler←arner-relaz←ted criteria it {5218}  {11808}←←← {3529}←, the corpus is←←←←←←←←←←←←←← {29572} thus th ←e internal aspects of {8387} the learners,  {3899}←←: {2201}←, it←←the corpus  {6891}i {6892}n {6123}←←contains ←←←←←←←←←←←←←←←←←←← {4663}←it needs to be  {8964}←←←←←←←←←←←←further need ←s to be  {4816}captured tht tha←ey←←←←←←at  {2050}t {2051}he learners are  {18053}students fo←rom 8←eight to sict←←xteen. {4317}  {3162}Taking  {6100}←←←←←←he mode is  {2275}spo←←←←←←of this  {4919}fictive corpus is written,  {6451}and  {9601}←←←←←← and {9510} the texts are essays  {17361}written in ←←←during school lessons.  {4667}If w e←←e {9063}foc←←← focalise the task- {2580}rel←←←←←←←←←←←←←←←←←←←←←←←←←←←That also gives information about the  {5906} and as homeworks← {2495}t {2495}ask-related {3256} crita←eria. {3716} The texts are pr←←more or less preparted and the time limitation ←←←←←←←←←←←←←←←←←←←←←←←←←←←←← {3405} more or lessis given since all students have the same d←time during class. {10071}The lecture also covere ←d  {2005}the goals and aims of the learner corpus research, which I am gpi←←oing to summarise in the following. {84755} It is {2828} help←←←←←←←←←← {5823}Inp← particula,←r, it is helpfulg←  {14533}to compa ...

# %% [markdown]
# # Visualization of Burst (Graph)

# %%
knew = pd.DataFrame()
i = 0
for idx, keyst in k[k['s_id']==126].iterrows():
    knew.at[idx,'t'] = keyst['t'] if keyst['t'] <10000 else 10000
    knew.at[idx,'char'] = keyst['char'] if str(keyst['char']) != 'nan' else '←'
    knew.at[idx,'id'] = idx
    if i >0:
        knew.at[previd,'midx'] = (knew.at[previd,'id'] + knew.at[idx,'id'])/2
        knew.at[previd,'midy'] = (knew.at[previd,'t'] + knew.at[idx,'t'])/2
    previd = idx
    i+=1
knew.at[idx,'midx'] = knew.at[idx,'id']
knew.at[idx,'midy'] = knew.at[idx,'t']
knew.index.name = 'knew_id'

# %%
ax = knew.plot(y='t',figsize=(15,5))
knew[['midx','midy','char']].apply(lambda x: ax.text(*x),axis=1);

# %% [markdown]
# # Word Frequency vs Pause Length

# %%
import string
wordlist = []
freqlist = []
tlist = []
tmedlist=[]
numlist = []
allowed = 'abcdefghijklmnopqrstuvwxyz'
len_4_words = w[(w['text_len'] == 11) & (w['spell_err'] == 0)]
gp = len_4_words.groupby(by='text')
for name,group in gp:
    if all(c in allowed for c in name):
        wordfreq = group['word_freq'].iloc[0]
        t_avg = group['t/len_filter_10000'].mean()
        t_med = group['t/len_filter_10000'].median()
        wordlist.append(name)
        freqlist.append(wordfreq)
        tlist.append(t_avg)
        tmedlist.append(t_med)
        numlist.append(len(group))

# %%
freq_t = pd.DataFrame()
freq_t['word'] = wordlist
freq_t['word frequency'] = freqlist
freq_t['t'] = tlist
freq_t['t_med'] = tmedlist
freq_t['occ'] = numlist
freq_t['log_t'] = np.log(1+freq_t['t'])
freq_t['log_t_med'] = np.log(1+freq_t['t_med'])

# %%
freq_t['word_freq'],bins = pd.qcut(freq_t['word frequency'],20,duplicates = 'drop',retbins=True)
ax = sns.boxplot(x="word_freq", y='t', data=freq_t,showfliers=False)
ax.set_xticks([])
print(bins)
# Out:
# [  0.00000000e+00   8.89000000e-08   1.78000000e-07   3.29950000e-07
#    5.01000000e-07   7.54500000e-07   1.04100000e-06   1.53600000e-06
#    2.02400000e-06   2.51000000e-06   3.09000000e-06   3.84050000e-06
#    5.01000000e-06   6.31000000e-06   7.76000000e-06   1.00000000e-05
#    1.32600000e-05   1.66600000e-05   2.34600000e-05   3.41050000e-05
#    2.63000000e-04]

# %%
freq_t['occ_gp'],bins = pd.qcut(freq_t['occ'],10,duplicates = 'drop',retbins=True)
ax = sns.boxplot(x='occ_gp', y='t', data=freq_t,showfliers=False)
ax.set_xticks([])
print(bins)
# Out:
# [  1.00000000e+00   2.00000000e+00   4.00000000e+00   7.00000000e+00
#    1.20000000e+01   3.72000000e+01   9.50000000e+01   1.97600000e+03]

# %%
freq_t['word_frequency'],bins = pd.qcut(freq_t['word frequency'],10,duplicates = 'drop',retbins = True)
ax = sns.boxplot(x="word_frequency", y='t_med', data=freq_t,showfliers=False)
ax.set_xticks([])
print(bins)
# Out:
# [  0.00000000e+00   1.78000000e-07   5.01000000e-07   1.04100000e-06
#    2.02400000e-06   3.09000000e-06   5.01000000e-06   7.76000000e-06
#    1.32600000e-05   2.34600000e-05   2.63000000e-04]

# %%
freq_t.corr()
# Out:
#                 word frequency         t     t_med       occ     log_t  \
# word frequency        1.000000 -0.082004 -0.119910  0.441388 -0.049320
# t                    -0.082004  1.000000  0.963127 -0.078873  0.759336
# t_med                -0.119910  0.963127  1.000000 -0.114330  0.707858
# occ                   0.441388 -0.078873 -0.114330  1.000000 -0.041533
# log_t                -0.049320  0.759336  0.707858 -0.041533  1.000000
# log_t_med            -0.144672  0.747546  0.778975 -0.133313  0.928420
#
#                 log_t_med
# word frequency  -0.144672
# t                0.747546
# t_med            0.778975
# occ             -0.133313
# log_t            0.928420
# log_t_med        1.000000

# %%
freq_t['occurrence'],bins = pd.qcut(freq_t['occ'],10,duplicates = 'drop',retbins = True)
ax = sns.boxplot(x='occurrence', y='t_med', data=freq_t,showfliers=False)
ax.set_xticks([])
print(bins)
# Out:
# [  1.00000000e+00   2.00000000e+00   4.00000000e+00   7.00000000e+00
#    1.20000000e+01   3.72000000e+01   9.50000000e+01   1.97600000e+03]

# %% [markdown]
# # Categorize Keystrokes

# %% [markdown]
# ### Get keystroke types

# %% [raw]
# k_sorted = k.sort_values(by='f_id')
# rs = 0; re = 0; ranges = {}
# for idx, val in k_sorted['f_id'].value_counts().sort_index().iteritems():
#     re += val
#     ranges[idx] = (rs, re)
#     rs += val

# %% [raw]
# for f_id, row in f.iterrows():
#     if ranges.get(f_id) != None:
#         u, v = ranges.get(f_id)
#         k_file = k_sorted.iloc[u:v, :]
#     else:
#         k_file = k_sorted.iloc[0:0, :]
#     #######
#     text = f.at[f_id, 'text']
#     for idx, row in k_file.iterrows():
#         ps = row['pos']
#         if ps<len(text)-1 and ps>0:
#             if text[ps].isalpha() or text[ps].isdigit():
#                 if text[ps-1].isalpha() or text[ps-1].isdigit():
#                     # inside a word
#                     k.at[idx,'keyst_type'] = 0
#                 else:
#                     if ps>1 and text[ps-1] == ' ' and text[ps-2] == '.':
#                         # space after period/comma/etc.
#                         k.at[idx,'keyst_type'] = 4
#                     elif text[ps-1] == ' ':
#                         # space after word before word
#                         k.at[idx,'keyst_type'] = 2
#                     else:
#                         k.at[idx,'keyst_type'] = -1
#             elif text[ps] == ' ':
#                 if (text[ps-1].isalpha() or text[ps-1].isdigit()) and (text[ps+1].isalpha() or text[ps+1].isdigit()):
#                     # last character of word
#                     k.at[idx,'keyst_type'] = 1
#                 elif (text[ps+1].isalpha() or text[ps+1].isdigit()) and text[ps-1] == '.':
#                     # period (end of sentence)
#                     k.at[idx,'keyst_type'] = 3
#                 else:
#                     k.at[idx,'keyst_type'] = -1
#             else:
#                 k.at[idx,'keyst_type'] = -1
#
#         else:
#             # first or last char of file
#             k.at[idx,'keyst_type'] = -1

# %%
k_sorted_type = k.sort_values(by = 'keyst_type')
k_filtered =  k_sorted_type[k_sorted_type['t']<10000]

# %%
keytype_mean= k_filtered.groupby(by='keyst_type')['t'].mean()
keytype_median = k_filtered.groupby(by='keyst_type')['t'].median()
keytype_count = k_filtered.groupby(by='keyst_type').size()
description = ['not classified','within words','between words(last char)','between words(space)','between sentences(period)','between sentences(space)']
typd = {'mean': keytype_mean, 'median': keytype_median, 'count': keytype_count,'description':description}
typdf = pd.DataFrame(data=typd)
typdf
# Out:
#               count                description        mean  median
# keyst_type
# -1.0         732823             not classified  704.277587     258
#  0.0        8983569               within words  283.525927     170
#  1.0        2022161   between words(last char)  375.577840     174
#  2.0        2743465       between words(space)  557.161356     249
#  3.0         111546  between sentences(period)  780.779069     495
#  4.0         206103   between sentences(space)  849.857595     252

# %% [markdown]
# # BiGrams

# %% [markdown]
# ### Get all Bigrams in data

# %% [raw]
# bigrcorp = pd.read_csv('../../pads/TokenizerAcadBigram.csv',delimiter = ';')

# %% [raw]
# bigrcorp.frequency_norm = (bigrcorp[' frequency']- bigrcorp[' frequency'].min())/(bigrcorp[' frequency'].max()- bigrcorp[' frequency'].min())

# %% [raw]
# bigr_freq = dict(zip(bigrcorp.bigram,bigrcorp.frequency_norm))

# %% [raw]
# lst = []
# for i,row in w.iterrows():
#     if w.at[i,'s_id'] == w.at[i+1,'s_id']:
#         w1 = w.at[i,'text']
#         w2 = w.at[i+1,'text']
#         bg = str(w1)+' '+str(w2)
#         spellerr = 1 if w.at[i,'spell_err'] == 1 or w.at[i+1,'spell_err'] == 1 else 0
#         bigram_freq = bigr_freq[bg] if bg in bigr_freq else 0
#         word_freq = w.at[i,'word_freq']*w.at[i+1,'word_freq']
#         l1 = w.at[i,'text_len']
#         l2 = w.at[i+1,'text_len']
#         text_len = l1+l2
#         k_count = w.at[i,'k_count']+w.at[i+1,'k_count']
#         t = w.at[i,'t']+w.at[i+1,'t']
#         t_over_len = t/text_len
#         t_over_len_filter_2000 = (w.at[i,'t/len_filter_2000']*l1+w.at[i+1,'t/len_filter_2000']*l2)/text_len
#         t_over_len_filter_10000 = (w.at[i,'t/len_filter_10000']*l1+w.at[i+1,'t/len_filter_10000']*l2)/text_len
#         max_p = max(w.at[i,'max_p'],w.at[i+1,'max_p'])
#         n_revisions = w.at[i,'n_revisions']+w.at[i+1,'n_revisions']
#         rowdict = {'s_id': w.at[i,'s_id'],'f_id':w.at[i,'f_id'],'u_id':w.at[i,'u_id'],'text':bg,'start_pos' : w.at[i,'start_pos'],
#                    'end_pos' : w.at[i+1,'end_pos'],'path' : w.at[i,'path'],
#                    'spell_err':spellerr,'bigram_freq':bigram_freq,'word_freq':word_freq,'text_len':text_len,
#                    'k_count':k_count,'t':t,'t/len':t_over_len,'t/len_filter_2000':t_over_len_filter_2000,
#                    't/len_filter_10000':t_over_len_filter_10000,'max_p':max_p,'n_revisions':n_revisions}
#         lst.append(rowdict)

# %% [raw]
# bi_gram = pd.DataFrame(data=lst, columns = ['s_id','f_id','u_id','text','start_pos','end_pos','path','spell_err','bigram_freq','word_freq','text_len','k_count','t','t/len','t/len_filter_2000','t/len_filter_10000','max_p','n_revisions'])

# %% [raw]
# bi_gram.to_csv('../../pads/bigrams.csv',index=False)

# %% [raw]
# bi_gram = pd.read_csv('../../pads/bigrams.csv')
# bi_gram

# %% [raw]
# g = bi_gram.groupby('text')
# bi_gram_3 = g.filter(lambda x: len(x) > 3)

# %% [raw]
# groups = bi_gram_3.groupby(by='text')
# big_gp_lst = []
# for i,group in groups:
#     rdict = {'occ':len(group),'text': i,'bigram_freq':group.iloc[0]['bigram_freq'],
#     'word_freq':group.iloc[0]['word_freq'],
#     'text_len':group.iloc[0]['text_len'],
#     'k_count':group.iloc[0]['k_count'],
#     't' :group['t'].mean(),
#     't/len':group['t/len'].mean(),
#     't/len_filter_2000':group['t/len_filter_2000'].mean(),
#      't/len_filter_10000':group['t/len_filter_10000'].mean(),
#     'max_p':group['max_p'].max()}
#     big_gp_lst.append(rdict)

# %% [raw]
# bi_gram3 = pd.DataFrame(data=big_gp_lst, columns = ['occ','text','bigram_freq','word_freq','text_len','k_count','t','t/len','t/len_filter_2000','t/len_filter_10000','max_p','n_revisions'])

# %%
rg = np.arange(bi_gram3['bigram_freq_log'].min(), bi_gram3['bigram_freq_log'].quantile(0.999), 0.003)

rg2 = np.array([bi_gram3['bigram_freq_log'].quantile(1 - 0.01*i) for i in range(9, -1, -1)])
print(rg2)

bi_gram3['value_group'] = pd.cut(bi_gram3['bigram_freq_log'], bins=rg2)
ax = sns.boxplot(x="value_group", y="t/len_filter_10000", data=bi_gram3)
ax.set_yscale('log')
# Out:
# [ 0.00159617  0.00179621  0.0020416   0.00238529  0.00281825  0.00346135
#   0.00443372  0.00620483  0.01000656  0.69314718]

# %%
bigfreq_nozero = bi_gram3[bi_gram3['bigram_freq'] != 0]['bigram_freq']
bi_gram3['bigram_freq_group'] = pd.qcut(bigfreq_nozero, 10, duplicates = 'drop')
ax = sns.boxplot(x='bigram_freq_group', y="t/len_filter_10000", data=bi_gram3)
ax.set_yscale('log')

# %%
bi_gram3[(bi_gram3['text_len'] < 13) & (bi_gram3['text_len'] > 7)]['occ'].median()
# Out:
# 8.0

# %%
bi_gram3['bigram_freq'].quantile(0.9)
# Out:
# 0.0014290415561699125

# %%
bi_gram3[(bi_gram3['bigram_freq']<0.001)& (bi_gram3['bigram_freq']>0)]['bigram_freq'].hist(bins=100)

# %%
high =  bi_gram3[(bi_gram3['text_len'] == 8) & (bi_gram3['bigram_freq'] > 8*10**(-5))]
low = bi_gram3[(bi_gram3['text_len'] == 8) & (bi_gram3['bigram_freq'] < 5*10**(-5))]

# %%
plotDistributions(high['t/len_filter_10000'][:len(low)], low['t/len_filter_10000'])

# %%
bi_gram3.corr(method = 'pearson')
# Out:
#                          occ  bigram_freq  word_freq  text_len   k_count  \
# occ                 1.000000     0.782187   0.316242 -0.081812 -0.040043
# bigram_freq         0.782187     1.000000   0.357542 -0.088017 -0.041262
# word_freq           0.316242     0.357542   1.000000 -0.153839 -0.058738
# text_len           -0.081812    -0.088017  -0.153839  1.000000  0.385687
# k_count            -0.040043    -0.041262  -0.058738  0.385687  1.000000
# t                  -0.001003    -0.002117   0.001248 -0.007763 -0.000939
# t/len              -0.000668    -0.001157   0.002131 -0.011408 -0.004190
# t/len_filter_2000  -0.000989     0.003385   0.119020 -0.326610  0.117301
# t/len_filter_10000 -0.000350    -0.000273   0.119715 -0.287819  0.092048
# max_p               0.068747     0.016569   0.020492 -0.010080 -0.000512
# n_revisions              NaN          NaN        NaN       NaN       NaN
# bigram_freq_log     0.795696     0.990122   0.366093 -0.104950 -0.048930
#
#                            t     t/len  t/len_filter_2000  t/len_filter_10000  \
# occ                -0.001003 -0.000668          -0.000989           -0.000350
# bigram_freq        -0.002117 -0.001157           0.003385           -0.000273
# word_freq           0.001248  0.002131           0.119020            0.119715
# text_len           -0.007763 -0.011408          -0.326610           -0.287819
# k_count            -0.000939 -0.004190           0.117301            0.092048
# t                   1.000000  0.958719           0.021832            0.038617
# t/len               0.958719  1.000000           0.014101            0.024041
# t/len_filter_2000   0.021832  0.014101           1.000000            0.922789
# t/len_filter_10000  0.038617  0.024041           0.922789            1.000000
# max_p               0.940332  0.915050           0.028817            0.047525
# n_revisions              NaN       NaN                NaN                 NaN
# bigram_freq_log    -0.002566 -0.001404           0.003735           -0.000664
#
#                        max_p  n_revisions  bigram_freq_log
# occ                 0.068747          NaN         0.795696
# bigram_freq         0.016569          NaN         0.990122
# word_freq           0.020492          NaN         0.366093
# text_len           -0.010080          NaN        -0.104950
# k_count            -0.000512          NaN        -0.048930
# t                   0.940332          NaN        -0.002566
# t/len               0.915050          NaN        -0.001404
# t/len_filter_2000   0.028817          NaN         0.003735
# t/len_filter_10000  0.047525          NaN        -0.000664
# max_p               1.000000          NaN         0.017758
# n_revisions              NaN          NaN              NaN
# bigram_freq_log     0.017758          NaN         1.000000

# %% [markdown]
# # Tri-grams

# %% [raw]
# trigrcorp = pd.read_csv('../../pads/trig_corp.csv',delimiter = ';')

# %% [raw]
# trigrcorp.frequency_norm = (trigrcorp.frequency- trigrcorp.frequency.min())/(trigrcorp.frequency.max()- trigrcorp.frequency.min())

# %% [raw]
# trigr_freq = dict(zip(trigrcorp.trigram,trigrcorp.frequency_norm))

# %% [raw]
# trdictlst = []
# for i,row in w.iterrows():
#     if w.at[i,'s_id'] == w.at[i+1,'s_id'] and w.at[i+1,'s_id'] == w.at[i+2,'s_id']:
#         w1 = w.at[i,'text']
#         w2 = w.at[i+1,'text']
#         w3 = w.at[i+2,'text']
#         tg = str(w1)+' '+str(w2)+' '+str(w3)
#         spellerr = 1 if w.at[i,'spell_err'] == 1 or w.at[i+1,'spell_err'] == 1 or w.at[i+2,'spell_err'] == 1 else 0
#         trigram_freq = trigr_freq[tg] if tg in trigr_freq else 0
#         word_freq = w.at[i,'word_freq']*w.at[i+1,'word_freq']*w.at[i+2,'word_freq']
#         l1 = w.at[i,'text_len']
#         l2 = w.at[i+1,'text_len']
#         l3 = w.at[i+2,'text_len']
#         text_len = l1+l2+l3
#         k_count = w.at[i,'k_count']+w.at[i+1,'k_count']+w.at[i+2,'k_count']
#         t = w.at[i,'t']+w.at[i+1,'t']+w.at[i+2,'t']
#         t_over_len = t/text_len
#         t_over_len_filter_2000 = (w.at[i,'t/len_filter_2000']*l1+w.at[i+1,'t/len_filter_2000']*l2+w.at[i+2,'t/len_filter_2000']*l3)/text_len
#         t_over_len_filter_10000 = (w.at[i,'t/len_filter_10000']*l1+w.at[i+1,'t/len_filter_10000']*l2+w.at[i+2,'t/len_filter_10000']*l3)/text_len
#         max_p = max(w.at[i,'max_p'],w.at[i+1,'max_p'],w.at[i+2,'max_p'])
#         n_revisions = w.at[i,'n_revisions']+w.at[i+1,'n_revisions']+w.at[i+2,'n_revisions']
#         rowdict = {'s_id': w.at[i,'s_id'],'f_id':w.at[i,'f_id'],'u_id':w.at[i,'u_id'],'text':tg,'start_pos' : w.at[i,'start_pos'],
#                    'end_pos' : w.at[i+2,'end_pos'],'path' : w.at[i,'path'],
#                    'spell_err':spellerr,'trigram_freq':trigram_freq,'word_freq':word_freq,'text_len':text_len,
#                    'k_count':k_count,'t':t,'t/len':t_over_len,'t/len_filter_2000':t_over_len_filter_2000,
#                    't/len_filter_10000':t_over_len_filter_10000,'max_p':max_p,'n_revisions':n_revisions}
#         trdictlst.append(rowdict)

# %% [raw]
# tri_gram = pd.DataFrame(data=trdictlst, columns = ['s_id','f_id','u_id','text','start_pos','end_pos','path','spell_err','trigram_freq','word_freq','text_len','k_count','t','t/len','t/len_filter_2000','t/len_filter_10000','max_p','n_revisions'])

# %% [raw]
# tri_gram.to_csv('../../pads/trigrams.csv',index=False)

# %% [raw]
# tri_group = tri_gram.groupby('text')
# tri_gram_3 = tri_group.filter(lambda x: len(x) > 3)

# %% [raw]
# groups = tri_gram_3.groupby(by='text')
# tri_gp_lst = []
# for i,group in groups:
#     rdict = {'occ':len(group),'text': i,'trigram_freq':group.iloc[0]['trigram_freq'],
#     'word_freq':group.iloc[0]['word_freq'],
#     'text_len':group.iloc[0]['text_len'],
#     'k_count':group.iloc[0]['k_count'],
#     't' :group['t'].mean(),
#     't/len':group['t/len'].mean(),
#     't/len_filter_2000':group['t/len_filter_2000'].mean(),
#      't/len_filter_10000':group['t/len_filter_10000'].mean(),
#     'max_p':group['max_p'].max()}
#     tri_gp_lst.append(rdict)

# %% [raw]
# tri_gram3 = pd.DataFrame(data=tri_gp_lst, columns = ['occ','text','trigram_freq','word_freq','text_len','k_count','t','t/len','t/len_filter_2000','t/len_filter_10000','max_p','n_revisions'])

# %%
tri_gram3[''] = pd.qcut(tri_gram3['trigram_freq'], 10, duplicates = 'drop')
ax = sns.boxplot(x='t/len_10000_grouped', y="t/len_filter_10000", data=tri_gram3)
ax.set_yscale('log')

# %% [markdown]
# # Get Pause Length for space

# %%
# new_t is pause length (from previous char to current char) + (from current char to next char)
k['new_t'] = k['t'] + k.shift(-1)['t']

# %%
spaces = k[(k['char'] == ' ')]

# %%
spaces['w_before'] = spaces['w_id']-1
spaces['w_after'] = spaces['w_id']
# Out:
# /Users/joohyunlee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/joohyunlee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Get Burst List

# %%
# takes in file id and pause threshold (ms)
# returns tuple list where the tuple is 
# (word id of start of burst, word id of end of burst, pause length after burst)
def get_burstlist_words2(file_id,p_threshold):
    burstlst = []
    stsid = f.loc[file_id,'s_id_s']
    steid = f.loc[file_id,'s_id_e']
#     sp_in_f = spaces[(spaces['s_id']>=stsid)&(spaces['s_id']<=steid)]
    sp_in_f = spaces[spaces['f_id']==file_id]
    tmean = sp_in_f['new_t'].mean()
    tmed = sp_in_f['new_t'].median()
    prev = sp_in_f.iloc[0]['w_before']
    for i in range(len(sp_in_f)):
        ks = sp_in_f.iloc[i]
        if ks['new_t'] > p_threshold:
            burstlst.append((prev+1,ks['w_before'],ks['new_t']))
            prev = ks['w_before']
    return burstlst,tmean,tmed

# %%
blist,tmean,tmed = get_burstlist_words2(0,550)
bstrlst = []
bstrlstjoin = []
for (w1,w2,p) in blist:
    if w1 != -2 and w1 != -1 and w2 != -1 and w2 != -2:
        burststrlst = [str(st) for st in w.loc[w1:w2,'text']]
        burststr =' '.join(str(st) for st in w.loc[w1:w2,'text'])
        print(burststr,end='')
        print(' {'+str(p)+'}',end='')
        bstrlst.append(burststrlst)
        bstrlstjoin.append(burststr)
# print(bstrlst)
print(blist)
# Out:
#  {759.0}second session dealt with Language {826.0}Acquisition {11570.0}In the following I will describe the most important terms as {5512.0}assigned The first important term is Second {654.0}language {601.0}A second language {8881.0}is any language that {1394.0}you {1150.0}acquire after {1305.0} {4242.0}your earliest {1770.0}childhood {1844.0}which {681.0}years {2748.0}of age {773.0}It is a language that {1286.0}you do not acquire from your parents {14921.0}It is important to {703.0}language is used as an umbrella term {34833.0}for any {1483.0}language acquired {9807.0}in {1403.0}the later terms of your life {7190.0}Language skills are also an important part of language acquistition There are four language skills that you need to acquire in order to be proficient in a {734.0}language {5640.0}These four skills are {1253.0}writing {628.0}skills listening skills {1537.0}speaking skills and reading skills {2377.0}They are further {641.0} {2313.0}classified into {5017.0}productive {2103.0}and speaking and {795.0}The first important {1329.0}term is {2772.0}Second language A second language is any language that you acquire after your earliest childhood which would be from around to years of age It is a language that you do not acquire from your parents It is important to note that the term second language is used as an umbrella term for any language acquired in the later terms of your life {925.0}Language skills {5804.0}are {918.0}also {1165.0}an {765.0}important part of language acquistition There are four language skills that you need to acquire in order to be proficient in a language These four skills are writing skills listening skills speaking skills and reading skills They are further classified into productive skills writing and speaking and receptive skills listening and reading To distinguish different {5392.0} {7243.0} {931.0}To {641.0}distinguish {959.0}different {1510.0}levels of language proficiency you need some sort of benchmark a {4296.0}so-called Language-learning Target {3811.0}It is {2892.0}used as a comparison a standard {685.0}that you can {6430.0}hold up against {1018.0}the {1302.0}skill level of {628.0}a language learner {1971.0}In this {629.0}case {643.0}the {922.0}most {16943.0}evident {1152.0}benchmark to use would be {1486.0}the {3104.0}language performance of a native speaker {3758.0}But this {22318.0}brings {673.0}forth a {4157.0}problem since {1838.0}native speakers actually do not speak flawlessly they make mistakes {629.0}or use {886.0}certain {3001.0}Native language {1017.0}competence {3968.0}will differ {700.0}language is not a {681.0}static system {4288.0}So {2623.0}a native speaker as the only benchmark {1812.0}can be very misleading {17230.0}To {10540.0}examine {12904.0}language {669.0}competence {2837.0}in {9535.0}practice {6179.0}there are {8290.0}two theories {1910.0}which you can apply {757.0}to {5212.0}your studies {10799.0}One of them {2879.0}is the Property Therory {2549.0} {1110.0} {1654.0}in which {600.0}you {2480.0}take different groups {5573.0}of people at a {2504.0}certain {687.0}place in time and test their {1976.0}knowledge {1015.0}to then compare it {5787.0}This theory {1220.0}allows {672.0}you {912.0}an insight {754.0}on competence at {1641.0}one point in time contrary to {1022.0}the Transition {749.0}Theory {3574.0}which is a longitudinal {756.0}study {676.0}Here you will {5191.0}need {645.0}to track {2029.0}one {671.0}or more people {2358.0}over a longer period of time in order to {2120.0}look at {755.0}development of skill {60331.0} {767.0}During the {617.0}process of {1076.0}learning a language {628.0}language learners will {7081.0}not be able {673.0}to {3403.0}for {637.0}quite a {643.0}while {119264.0}During this stage {2356.0}the language that {2686.0}is produced is {675.0}called {3030.0}Interlanguage {760.0}Interlanguage {1184.0} {9330.0} {1238.0}describes an in-between {1630.0}state of {774.0}L -learners {628.0}which is slightly flawed {2306.0}by {4022.0}generalizations {63 ...

# %% [markdown]
# ### Average Burst Length and Pause Length

# %% [raw]
# bst = pd.DataFrame()

# %% [raw]
# for fid in range(len(f)):
#     blist,tmean,tmed = get_burstlist_words2(fid,550)
#     burstlenlst = []
#     plst=[]
#     for (w1,w2,p) in blist:
#         if w1!=-1 and w1!=-2 and w2!=-1 and w2!=-2 and w1<=w2:
#             burstlenlst.append(w2-w1+1)
#             plst.append(p)
#     bst.at[fid,'file_id'] = fid
#     bst.at[fid,'u_id'] = f.at[fid,'u_id']
#     if len(burstlenlst)>0:
#         bst.at[fid,'avg_burst_len'] = sum(burstlenlst)/len(burstlenlst)
#         bst.at[fid,'mean_p'] = sum(plst)/len(plst)
#         bst.at[fid,'med_p'] = np.median(plst)

# %%
bst_2000.corr()
# Out:
#                 file_id      u_id  avg_burst_len    mean_p     med_p
# file_id        1.000000  0.976788       0.024408 -0.022093 -0.017114
# u_id           0.976788  1.000000       0.015918 -0.020658 -0.013346
# avg_burst_len  0.024408  0.015918       1.000000  0.027509 -0.006937
# mean_p        -0.022093 -0.020658       0.027509  1.000000  0.034602
# med_p         -0.017114 -0.013346      -0.006937  0.034602  1.000000

# %%
bst_1000['med_p_gp'],bins = pd.qcut(bst_1000['med_p'],15,duplicates = 'drop',retbins=True)
ax =sns.boxplot(x='med_p_gp', y='avg_burst_len',data=bst_1000,showfliers=False)
ax.set_xticks([])
ax.set_ylabel('Average Burst Length')
ax.set_xlabel('Median Pause Length')


print(bins)
# Out:
# [  1001.           1589.86666667   1773.           1896.           2016.86666667
#    2121.5          2221.6          2321.           2438.46666667   2561.7
#    2724.33333333   2914.13333333   3180.6          3655.26666667
#    4529.73333333  60599.        ]

# %%
x = bst_550.groupby(by='u_id').mean()['avg_burst_len'].reset_index(drop=True)
y = bst_550.groupby(by='u_id').mean()['med_p'].reset_index(drop=True)

# %%
burst_pause = pd.DataFrame()
burst_pause['bl'] = x
burst_pause['medp'] = y
burst_pause['bl_gp'],bins = pd.qcut(burst_pause['bl'],20,duplicates = 'drop',retbins=True)
ax = sns.boxplot(x='bl_gp', y='medp', data=burst_pause,showfliers=False)
ax.set_xticks([])
burst_pause.plot.hexbin(x='bl',y='medp',sharex=False)

# %%
bst_550.corr()
# Out:
#                 file_id      u_id  avg_burst_len    mean_p     med_p
# file_id        1.000000  0.976788       0.032570 -0.027008  0.023010
# u_id           0.976788  1.000000       0.027011 -0.025290  0.019418
# avg_burst_len  0.032570  0.027011       1.000000  0.001328  0.412974
# mean_p        -0.027008 -0.025290       0.001328  1.000000  0.011960
# med_p          0.023010  0.019418       0.412974  0.011960  1.000000

# %% [markdown]
# ### Average Burst length from old to recent files for each user

# %%
# for i in range(14):
gp  = bst_550.groupby(by='u_id')
tot_lst = np.zeros((1,12))
for u_id,group in gp:
    group = group.sort_values(by='file_id')
    if u_id != 496 and len(group) == 12:
        gp_lst =group['avg_burst_len'].tolist()
        tot_lst = np.append(tot_lst, np.array([gp_lst]), axis=0)
print(np.nanmean(tot_lst,axis=0))
print(len(tot_lst))
plt.plot(np.nanmean(tot_lst,axis=0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49a6088e425b> in <module>()
#       1 # for i in range(14):
# ----> 2 gp  = bst_550.groupby(by='u_id')
#       3 tot_lst = np.zeros((1,12))
#       4 for u_id,group in gp:
#       5     group = group.sort_values(by='file_id')
#
# NameError: name 'bst_550' is not defined

# %% [markdown]
# # N-gram Frequency : Across Burst vs Within Burst

# %% [markdown]
# ### Bigram

# %% [raw]
# file_freq = []
# for fid in range(len(f)):
#     blist,tmean,tmed = get_burstlist_words2(fid,2000)
#     blist,_,_ = get_burstlist_words2(fid,2*tmed)
#     bstrlst = []
#     for (w1,w2,p) in blist:
#         if w1 != -2 and w1 != -1 and w2 != -1 and w2 != -2:
#             burststrlst = [str(st) for st in w.loc[w1:w2,'text']]
#             bstrlst.append(burststrlst)
#
#     avglst = []
#     for bst in bstrlst:
#         if len(bst)>1:
#             freqsum = 0
#             for i in range(len(bst)-1):
#                 bigr = ' '.join(bst[i:i+2])
#                 freqsum += np.log(1+bigr_freq[bigr]) if bigr in bigr_freq else 0
#             avglst.append(freqsum/(len(bst)-1))
#     burst_freq_avg = sum(avglst)/len(avglst) if len(avglst)>0 else -1
#
#     cross_avglst = []
#     for i in range(len(bstrlst)-1):
#         if len(bstrlst[i])>=1 and len(bstrlst[i+1])>=1:
#             burst1 = bstrlst[i]
#             burst2 = bstrlst[i+1]
#             bigr = burst1[len(burst1)-1]+' '+burst2[0]
#             cross_avglst.append(np.log(1+bigr_freq[bigr]) if bigr in bigr_freq else 0)
#     cross_freq_avg = sum(cross_avglst)/len(cross_avglst) if len(cross_avglst)>0 else -1
#     if burst_freq_avg != -1 and cross_freq_avg != -1:
#         file_freq.append((fid,burst_freq_avg,cross_freq_avg))

# %% [raw]
# burst_bigr_freq_2tmed = pd.DataFrame()
# for i in range(len(file_freq)):
#     burst_bigr_freq_2tmed.at[i,'file_id'] = file_freq[i][0]
#     burst_bigr_freq_2tmed.at[i,'burst_freq'] = file_freq[i][1]
#     burst_bigr_freq_2tmed.at[i,'across_burst_freq'] = file_freq[i][2]

# %% [markdown]
# ### T-statistics

# %%
from scipy.stats import ttest_ind
data1, data2 = burst_trgr_freq_2000['burst_freq'],burst_trgr_freq_2000['across_burst_freq']
stat, p = ttest_ind(data1, data2,equal_var=False)
print(stat)
print(p)
# Out:
# 56.2489479571
# 0.0

# %%
plotDistributions(burst_bigr_freq_tmed['burst_freq'],burst_bigr_freq_tmed['across_burst_freq'],label1='within burst', label2='across burst', x_label='bigram frequency (2*median)')

# %%
plotDistributions(burst_bigr_freq['burst_freq'],burst_bigr_freq['across_burst_freq'],label1='within burst', label2='across burst', x_label='bigram frequency (550ms)')

# %%
plotDistributions(burst_bigr_freq_1000['burst_freq'],burst_bigr_freq_1000['across_burst_freq'],label1='within burst', label2='across burst', x_label='bigram frequency (1000ms)')

# %%
plotDistributions(burst_bigr_freq_2000['burst_freq'],burst_bigr_freq_2000['across_burst_freq'],label1='within burst', label2='across burst', x_label='bigram frequency (2000ms)')

# %% [markdown]
# ### Trigram

# %% [raw]
# file_freq = []
# for fid in range(len(f)):
#     blist,tmean,tmed = get_burstlist_words2(fid,2000)
#     blist,_,_ = get_burstlist_words2(fid,2*tmed)
#     bstrlst = []
#     for (w1,w2,p) in blist:
#         if w1 != -2 and w1 != -1 and w2 != -1 and w2 != -2:
#             burststrlst = [str(st) for st in w.loc[w1:w2,'text']]
#             bstrlst.append(burststrlst)
#
#     avglst = []
#     for bst in bstrlst:
#         if len(bst)>1:
#             freqsum = 0
#             for i in range(len(bst)-1):
#                 trgr = ' '.join(bst[i:i+3])
#                 freqsum += np.log(1+trgr_freq[trgr]) if trgr in trgr_freq else 0
#             avglst.append(freqsum/(len(bst)-1))
#     burst_freq_avg = sum(avglst)/len(avglst) if len(avglst)>0 else -1
#
#     cross_avglst = []
#     for i in range(len(bstrlst)-1):
#         if len(bstrlst[i])>=2 and len(bstrlst[i+1])>=2:
#             burst1 = bstrlst[i]
#             burst2 = bstrlst[i+1]
#             trgr = burst1[len(burst1)-1]+' '+burst2[0]+' '+burst2[1]
#             trgr2 = burst1[len(burst1)-1]+' '+burst1[len(burst1)-1]+' '+burst2[0]
#             score1 = 0
#             score2 = 0
#             if trgr in trgr_freq:
#                 score1 = np.log(1+trgr_freq[trgr])
#             if trgr2 in trgr_freq:
#                 score2 = np.log(1+trgr_freq[trgr2])
#             cross_avglst.append((score1+score2)/2)
#     cross_freq_avg = sum(cross_avglst)/len(cross_avglst) if len(cross_avglst)>0 else -1
#     if burst_freq_avg != -1 and cross_freq_avg != -1:
#         file_freq.append((fid,burst_freq_avg,cross_freq_avg))

# %% [raw]
# burst_trgr_freq_tmed = pd.DataFrame()
# for i in range(len(file_freq)):
#     burst_trgr_freq_tmed.at[i,'file_id'] = file_freq[i][0]
#     burst_trgr_freq_tmed.at[i,'burst_freq'] = file_freq[i][1]
#     burst_trgr_freq_tmed.at[i,'across_burst_freq'] = file_freq[i][2]

# %%
plotDistributions(burst_trgr_freq_tmed['burst_freq'],burst_trgr_freq_tmed['across_burst_freq'],label1='within burst', label2='across burst', x_label='trigram frequency (2*med)')

# %%
plotDistributions(burst_trgr_freq_550['burst_freq'],burst_trgr_freq_550['across_burst_freq'],label1='within burst', label2='across burst', x_label='trigram frequency (550ms)')

# %%
plotDistributions(burst_trgr_freq_1000['burst_freq'],burst_trgr_freq_1000['across_burst_freq'],label1='within burst', label2='across burst', x_label='trigram frequency (1000ms)')

# %%
plotDistributions(burst_trgr_freq_2000['burst_freq'],burst_trgr_freq_2000['across_burst_freq'],label1='within burst', label2='across burst', x_label='trigram frequency (2000ms)')

# %%
burst_bigr_freq['burst_freq'].median()
# Out:
# 0.019225255247534614

# %%
burst_bigr_freq['across_burst_freq'].median()
# Out:
# 0.009128612395529888

# %%
avglst = []
for bst in bstrlst:
    if len(bst)>1:
        freqsum = 0
        for i in range(len(bst)-1):
            bigr = ' '.join(bst[i:i+2])
            freqsum += np.log(1+bigr_freq[bigr]) if bigr in bigr_freq else 0
        avglst.append(freqsum/(len(bst)-1))
sum(avglst)/len(avglst)
# Out:
# 0.015006122905251112

# %%
cross_avglst = []
for i in range(len(bstrlst)-1):
    if len(bstrlst[i])>=1 and len(bstrlst[i+1])>=1:
        burst1 = bstrlst[i]
        burst2 = bstrlst[i+1]
        bigr = burst1[len(burst1)-1]+' '+burst2[0]
        cross_avglst.append(np.log(1+bigr_freq[bigr]) if bigr in bigr_freq else 0)
sum(cross_avglst)/len(cross_avglst)
# Out:
# 0.010138069542753807

# %%
def get_burst_sent(s_id,p_thresh):
    burstlst = []
    s_space = spaces[spaces['s_id']==s_id]
    prev = s_space.iloc[0]['w_id']
    for j in range(1,len(s_space)):
        if s_space.iloc[j]['new_t']> p_thresh:
            b_start = prev+1
            b_end = s_space.iloc[j]['w_before']
            if b_start<=b_end and b_start != -1 and b_end != -1 and b_start != -2 and b_end != -2:
                print(b_start)
                print(b_end)
                burst = [str(st) for st in w.loc[b_start:b_end,'text']]
                prev = b_end
                burstlst.append(burst)
    return burstlst

# %% [markdown]
# # Writing to file

# %%
burst_bigr_freq_2tmed.to_csv('../../pads/burstbigrfreq_tmed.csv',index=False)
burst_trgr_freq_tmed.to_csv('../../pads/bursttrgrfreq_tmed.csv',index=False)

# %%
burst_bigr_freq_1000.to_csv('../../pads/burstbigrfreq_1000.csv',index=False)
burst_bigr_freq_2000.to_csv('../../pads/burstbigrfreq_2000.csv',index=False)
burst_trgr_freq_550.to_csv('../../pads/bursttrgrfreq_500.csv',index=False)
burst_trgr_freq_1000.to_csv('../../pads/bursttrgrfreq_1000.csv',index=False)

# %%
burst_trgr_freq_2000.to_csv('../../pads/bursttrgrfreq_2000.csv',index=False)

# %%
burst_bigr_freq.to_csv('../../pads/burstbigrfreq.csv',index=False)

# %%
k.to_csv('../../pads/keystrokes.csv', index=False)

# %%
k.to_csv('../../pads/keystrokes.csv', index=False)
w.to_csv('../../pads/words.csv', index=False)
s.to_csv('../../pads/sentences.csv', index=False)
f.to_csv('../../pads/files.csv', index=False)
u.to_csv('../../pads/users.csv', index=False)
